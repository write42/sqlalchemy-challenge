# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from sqlalchemy import desc

# %%
engine = create_engine("sqlite:///hawaii.sqlite")
conn = engine.connect()

# %%
# reflect an existing database into a new model

#engine.execute('SELECT * FROM measurement')
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# reflect the tables
# Out:
# ['measurement', 'station']

# %%
# We can view all of the classes that automap found

# %%
# Save references to each table
measurement = Base.classes.measurement
station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
measurement_row = session.query(measurement).first()
measurement_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1b7b928d730>,
#  'prcp': 0.08,
#  'station': 'USC00519397',
#  'tobs': 65.0,
#  'date': '2010-01-01',
#  'id': 1}

# %%
station_row = session.query(station).first()
station_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1b7b928dee0>,
#  'id': 1,
#  'elevation': 3.0,
#  'latitude': 21.2716,
#  'station': 'USC00519397',
#  'longitude': -157.8168,
#  'name': 'WAIKIKI 717.2, HI US'}

# %%
measurement_last = session.query(measurement.date).order_by(desc(measurement.date))
for x in measurement_last:
 print(x)
# Out:
# ('2017-08-23',)
# ('2017-08-23',)
# ('2017-08-23',)
# ('2017-08-23',)
# ('2017-08-22',)
# ('2017-08-22',)
# ('2017-08-22',)
# ('2017-08-21',)
# ('2017-08-21',)
# ('2017-08-21',)
# ('2017-08-21',)
# ('2017-08-20',)
# ('2017-08-20',)
# ('2017-08-20',)
# ('2017-08-19',)
# ('2017-08-19',)
# ('2017-08-19',)
# ('2017-08-19',)
# ('2017-08-18',)
# ('2017-08-18',)
# ('2017-08-18',)
# ('2017-08-18',)
# ('2017-08-17',)
# ('2017-08-17',)
# ('2017-08-17',)
# ('2017-08-17',)
# ('2017-08-16',)
# ('2017-08-16',)
# ('2017-08-16',)
# ('2017-08-16',)
# ('2017-08-15',)
# ('2017-08-15',)
# ('2017-08-15',)
# ('2017-08-15',)
# ('2017-08-15',)
# ('2017-08-14',)
# ('2017-08-14',)
# ('2017-08-14',)
# ('2017-08-14',)
# ('2017-08-14',)
# ('2017-08-13',)
# ('2017-08-13',)
# ('2017-08-13',)
# ('2017-08-13',)
# ('2017-08-13',)
# ('2017-08-12',)
# ('2017-08-12',)
# ('2017-08-12',)
# ('2017-08-11',)
# ('2017-08-11',)
# ('2017-08-11',)
# ('2017-08-11',)
# ('2017-08-10',)
# ('2017-08-10',)
# ('2017-08-10',)
# ...

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
#rain = session.query(measurement).filter(measurement.date >'2016-08-23').\
#filter(measurement.prcp)
# Calculate the date 1 year ago from the last data point in the database

# Perform a query to retrieve the data and precipitation scores

# Save the query results as a Pandas DataFrame and set the index to the date column
# pd.read_sql("SELECT * FROM measurement",conn)
inspector = inspect(engine)
#print(inspector.get_table_names())

df = pd.read_sql("SELECT date,prcp FROM measurement WHERE date > '2016-08-23'",conn)
df_next = df.dropna().sort_values("date")
# Sort the dataframe by date

# Use Pandas Plotting with Matplotlib to plot the data

# df_next.plot(kind="bar")
df_next.plot(x='date', y='prcp', rot=90)
plt.xlabel('Date')
plt.ylabel('Inches')
# Out:
# Text(0, 0.5, 'Inches')

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
df_next.describe()
# Out:
#               prcp
# count  2015.000000
# mean      0.176462
# std       0.460288
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %%
# Design a query to show how many stations are available in this dataset?
station_count = session.query(station.station).count()
station_count
# Out:
# 9

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
stations = pd.read_sql("SELECT station,date FROM measurement",conn)
stations
# Out:
#            station        date
# 0      USC00519397  2010-01-01
# 1      USC00519397  2010-01-02
# 2      USC00519397  2010-01-03
# 3      USC00519397  2010-01-04
# 4      USC00519397  2010-01-06
# ...            ...         ...
# 19545  USC00516128  2017-08-19
# 19546  USC00516128  2017-08-20
# 19547  USC00516128  2017-08-21
# 19548  USC00516128  2017-08-22
# 19549  USC00516128  2017-08-23
#
# [19550 rows x 2 columns]
